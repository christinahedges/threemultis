# %%
import characterizethis as ct
# Out:
# Database out of date. Redownloading...
# /Users/ch/K2/projects/characterizeTHIS/characterizethis/ct.py:84: RuntimeWarning: invalid value encountered in sqrt
#   l = (np.asarray((re + np.asarray(df.st_rad))**2) - (b*np.asarray(df.st_rad))**2)**0.5
# /Users/ch/K2/projects/characterizeTHIS/characterizethis/ct.py:114: RuntimeWarning: invalid value encountered in greater
#   flux[flux > saturation] = saturation

# %%
import exoplanet as xo
import numpy as np
import pymc3 as pm
# Out:
# /Users/ch/miniconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
df = ct.get_data()

# %%
c = df[(df.pl_tranflag == 1) & (df.pl_orbper < 30)].groupby('pl_hostname').count()

# %%
len(list(c[c['pl_letter'] >=3].index))
# Out:
# 123

# %%
t
# Out:
#      pl_hostname pl_letter  pl_disc          ra        dec  pl_trandep  \
# 0     Kepler-128         c     2013  282.492224  43.980213    0.000045
# 1     Kepler-129         b     2014  285.311284  47.848595    0.000175
# 2     Kepler-129         c     2014  285.311284  47.848595    0.000202
# 3     Kepler-130         b     2014  288.450665  40.245305    0.000068
# 4     Kepler-130         c     2014  288.450665  40.245305    0.064000
# 5     Kepler-130         d     2014  288.450665  40.245305    0.000176
# 6     Kepler-131         b     2014  288.530825  40.942304    0.000460
# 7     Kepler-131         c     2014  288.530825  40.942304    0.000056
# 8     Kepler-132         b     2014  283.235810  41.343037    0.000088
# 9     Kepler-132         c     2014  283.235810  41.343037    0.000099
# 10    Kepler-132         d     2014  283.235810  41.343037    0.000144
# 11    Kepler-133         b     2014  297.277976  48.320328    0.000127
# ...

# %%
with pm.Model() as model:
    u = xo.distributions.QuadLimbDark('u_star')
    print(u.random())
# Out:
# [0.2242202 0.3472362]

# %%
q = np.moveaxis(np.random.uniform(0, 1, size=2),
                        0, -1)

# %%
q
# Out:
# array([0.91458091, 0.51701544])
